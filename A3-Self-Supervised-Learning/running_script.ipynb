# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/A3-Self-Supervised-Learning
# Out:
# /content/drive/MyDrive/A3-Self-Supervised-Learning

# %%
# !python3 run.py --model dino --epochs 1 --train
# Out:
# Using device: cuda
# /usr/local/lib/python3.12/dist-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# Student parameters: 5,919,168
# 100% 170M/170M [2:04:40<00:00, 22.8kB/s]
# DINO 1/1: 100% 781/781 [02:15<00:00,  5.78it/s]
# Epoch 01 | Loss: 5.2709 | Center norm: 4.2960 | Time: 135.2s
#
# Total: 2.3 min | Avg/epoch: 135.2s
# Saved weights to: saved/dino.pt
# Saved stats to: saved/dino_stats.json

# %%
# !python3 run.py --model mae --mask-ratio 0.75 --epochs 1 --train
# Out:
# Using device: cuda
# /content/drive/MyDrive/A3-Self-Supervised-Learning/models.py:166: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=depth)
# /content/drive/MyDrive/A3-Self-Supervised-Learning/models.py:211: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(decoder_layer, num_layers=depth)
# MAE Encoder params: 2,678,976
# MAE Decoder params: 824,368 (30.8% of encoder)
# MAE 1/1: 100% 390/390 [00:12<00:00, 30.75it/s]
# Epoch 01 | Recon Loss: 0.7733 | Time: 12.7s
#
# Total: 0.2 min | Avg/epoch: 12.7s
# Saved weights to: saved/mae_encoder_mask075.pt
# Saved stats to: saved/mae_encoder_mask075_stats.json

# %%
# !python3 run.py --model dino --no-centering --epochs 50 --train
# Out:
# Using device: cuda
# /usr/local/lib/python3.12/dist-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# Student parameters: 5,919,168
# DINO 1/50: 100% 781/781 [02:12<00:00,  5.92it/s]
# Epoch 01 | Loss: 0.6763 | Center norm: 0.0000 | Time: 132.0s
# DINO 2/50: 100% 781/781 [02:17<00:00,  5.70it/s]
# Epoch 02 | Loss: 0.5420 | Center norm: 0.0000 | Time: 137.1s
# DINO 3/50: 100% 781/781 [02:18<00:00,  5.64it/s]
# Epoch 03 | Loss: 0.5057 | Center norm: 0.0000 | Time: 138.5s
# DINO 4/50: 100% 781/781 [02:18<00:00,  5.65it/s]
# Epoch 04 | Loss: 0.4856 | Center norm: 0.0000 | Time: 138.2s
# DINO 5/50: 100% 781/781 [02:18<00:00,  5.63it/s]
# Epoch 05 | Loss: 0.4676 | Center norm: 0.0000 | Time: 138.8s
# DINO 6/50: 100% 781/781 [02:17<00:00,  5.68it/s]
# Epoch 06 | Loss: 0.4540 | Center norm: 0.0000 | Time: 137.6s
# ...

# %%
# !python3 run.py --model dino --weights saved/dino_no_centering.pt --evaluate --linear
# Out:
# Using device: cuda
# /usr/local/lib/python3.12/dist-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# DINO Linear Eval 1/5: 100% 196/196 [00:06<00:00, 30.46it/s]
# Train Acc: 24.10%
# DINO Linear Eval 2/5: 100% 196/196 [00:06<00:00, 31.37it/s]
# Train Acc: 31.07%
# DINO Linear Eval 3/5: 100% 196/196 [00:06<00:00, 30.53it/s]
# Train Acc: 33.77%
# DINO Linear Eval 4/5: 100% 196/196 [00:06<00:00, 31.83it/s]
# Train Acc: 35.13%
# DINO Linear Eval 5/5: 100% 196/196 [00:06<00:00, 31.10it/s]
# Train Acc: 35.93%
#
# DINO Linear Eval Test Accuracy: 37.19%

# %%
# !python3 run.py --model dino --epochs 50 --train
# Out:
# Using device: cuda
# /usr/local/lib/python3.12/dist-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# Student parameters: 5,919,168
# DINO 1/50: 100% 781/781 [02:15<00:00,  5.75it/s]
# Epoch 01 | Loss: 5.2709 | Center norm: 4.2960 | Time: 135.8s
# DINO 2/50: 100% 781/781 [02:19<00:00,  5.60it/s]
# Epoch 02 | Loss: 4.8357 | Center norm: 5.9139 | Time: 139.4s
# DINO 3/50: 100% 781/781 [02:18<00:00,  5.65it/s]
# Epoch 03 | Loss: 4.5702 | Center norm: 7.6040 | Time: 138.3s
# DINO 4/50: 100% 781/781 [02:19<00:00,  5.59it/s]
# Epoch 04 | Loss: 4.3393 | Center norm: 8.6525 | Time: 139.8s
# DINO 5/50: 100% 781/781 [02:20<00:00,  5.57it/s]
# Epoch 05 | Loss: 4.1337 | Center norm: 9.6625 | Time: 140.2s
# DINO 6/50: 100% 781/781 [02:20<00:00,  5.57it/s]
# Epoch 06 | Loss: 3.9909 | Center norm: 10.8069 | Time: 140.3s
# ...

# %%
# !python3 run.py --model dino --weights saved/dino.pt --evaluate --linear
# Out:
# Using device: cuda
# /usr/local/lib/python3.12/dist-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# DINO Linear Eval 1/5: 100% 196/196 [00:06<00:00, 29.78it/s]
# Train Acc: 57.50%
# DINO Linear Eval 2/5: 100% 196/196 [00:06<00:00, 31.52it/s]
# Train Acc: 66.70%
# DINO Linear Eval 3/5: 100% 196/196 [00:06<00:00, 30.17it/s]
# Train Acc: 68.03%
# DINO Linear Eval 4/5: 100% 196/196 [00:06<00:00, 32.16it/s]
# Train Acc: 68.84%
# DINO Linear Eval 5/5: 100% 196/196 [00:06<00:00, 31.05it/s]
# Train Acc: 69.33%
#
# DINO Linear Eval Test Accuracy: 69.14%

# %%
# !python3 run.py --model dino --n-local 0 --epochs 50 --train
# Out:
# Using device: cuda
# /usr/local/lib/python3.12/dist-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# Student parameters: 5,919,168
# DINO 1/50: 100% 781/781 [00:56<00:00, 13.93it/s]
# Epoch 01 | Loss: 4.9652 | Center norm: 5.6537 | Time: 56.1s
# DINO 2/50: 100% 781/781 [00:55<00:00, 13.95it/s]
# Epoch 02 | Loss: 4.2228 | Center norm: 7.3627 | Time: 56.0s
# DINO 3/50: 100% 781/781 [00:54<00:00, 14.21it/s]
# Epoch 03 | Loss: 3.8188 | Center norm: 8.6068 | Time: 55.0s
# DINO 4/50: 100% 781/781 [00:55<00:00, 14.05it/s]
# Epoch 04 | Loss: 3.6350 | Center norm: 9.4975 | Time: 55.6s
# DINO 5/50: 100% 781/781 [00:55<00:00, 13.99it/s]
# Epoch 05 | Loss: 3.5076 | Center norm: 10.8635 | Time: 55.8s
# DINO 6/50: 100% 781/781 [00:55<00:00, 14.04it/s]
# Epoch 06 | Loss: 3.3792 | Center norm: 12.3840 | Time: 55.6s
# ...

# %%
# !python3 run.py --model dino --weights saved/dino_no_local.pt --evaluate --linear
# Out:
# Using device: cuda
# /usr/local/lib/python3.12/dist-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# DINO Linear Eval 1/5: 100% 196/196 [00:06<00:00, 31.35it/s]
# Train Acc: 52.71%
# DINO Linear Eval 2/5: 100% 196/196 [00:05<00:00, 32.75it/s]
# Train Acc: 60.18%
# DINO Linear Eval 3/5: 100% 196/196 [00:06<00:00, 32.21it/s]
# Train Acc: 61.94%
# DINO Linear Eval 4/5: 100% 196/196 [00:05<00:00, 32.74it/s]
# Train Acc: 62.82%
# DINO Linear Eval 5/5: 100% 196/196 [00:06<00:00, 31.47it/s]
# Train Acc: 63.47%
#
# DINO Linear Eval Test Accuracy: 62.82%

# %%
# !python3 run.py --model mae --mask-ratio 0.25 --epochs 50 --train
# Out:
# Using device: cuda
# /content/drive/MyDrive/A3-Self-Supervised-Learning/models.py:166: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=depth)
# /content/drive/MyDrive/A3-Self-Supervised-Learning/models.py:211: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(decoder_layer, num_layers=depth)
# MAE Encoder params: 2,678,976
# MAE Decoder params: 824,368 (30.8% of encoder)
# MAE 1/50: 100% 390/390 [00:13<00:00, 29.82it/s]
# Epoch 01 | Recon Loss: 0.7500 | Time: 13.1s
# MAE 2/50: 100% 390/390 [00:13<00:00, 28.66it/s]
# Epoch 02 | Recon Loss: 0.5233 | Time: 13.6s
# MAE 3/50: 100% 390/390 [00:12<00:00, 31.96it/s]
# Epoch 03 | Recon Loss: 0.4096 | Time: 12.2s
# MAE 4/50: 100% 390/390 [00:12<00:00, 30.35it/s]
# ...

# %%
# !python3 run.py --model mae    --weights saved/mae_encoder_mask025.pt --evaluate --linear
# Out:
# Using device: cuda
# /content/drive/MyDrive/A3-Self-Supervised-Learning/models.py:166: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=depth)
# /content/drive/MyDrive/A3-Self-Supervised-Learning/models.py:211: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(decoder_layer, num_layers=depth)
# MAE Linear Eval 1/5: 100% 196/196 [00:09<00:00, 19.69it/s]
# Train Acc: 33.79%
# MAE Linear Eval 2/5: 100% 196/196 [00:09<00:00, 20.23it/s]
# Train Acc: 41.22%
# MAE Linear Eval 3/5: 100% 196/196 [00:09<00:00, 19.90it/s]
# Train Acc: 42.85%
# MAE Linear Eval 4/5: 100% 196/196 [00:09<00:00, 20.31it/s]
# Train Acc: 43.69%
# MAE Linear Eval 5/5: 100% 196/196 [00:09<00:00, 19.68it/s]
# Train Acc: 44.44%
#
# ...

# %%
# !python3 run.py --model mae --mask-ratio 0.50 --epochs 50 --train
# Out:
# Using device: cuda
# /content/drive/MyDrive/A3-Self-Supervised-Learning/models.py:166: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=depth)
# /content/drive/MyDrive/A3-Self-Supervised-Learning/models.py:211: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(decoder_layer, num_layers=depth)
# MAE Encoder params: 2,678,976
# MAE Decoder params: 824,368 (30.8% of encoder)
# MAE 1/50: 100% 390/390 [00:12<00:00, 31.90it/s]
# Epoch 01 | Recon Loss: 0.7509 | Time: 12.2s
# MAE 2/50: 100% 390/390 [00:12<00:00, 32.26it/s]
# Epoch 02 | Recon Loss: 0.5776 | Time: 12.1s
# MAE 3/50: 100% 390/390 [00:12<00:00, 31.30it/s]
# Epoch 03 | Recon Loss: 0.4851 | Time: 12.5s
# MAE 4/50: 100% 390/390 [00:11<00:00, 33.46it/s]
# ...

# %%
# !python3 run.py --model mae    --weights saved/mae_encoder_mask05.pt --evaluate --linear
# Out:
# Using device: cuda
# /content/drive/MyDrive/A3-Self-Supervised-Learning/models.py:166: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=depth)
# /content/drive/MyDrive/A3-Self-Supervised-Learning/models.py:211: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(decoder_layer, num_layers=depth)
# MAE Linear Eval 1/5: 100% 196/196 [00:10<00:00, 19.43it/s]
# Train Acc: 35.15%
# MAE Linear Eval 2/5: 100% 196/196 [00:10<00:00, 19.55it/s]
# Train Acc: 42.49%
# MAE Linear Eval 3/5: 100% 196/196 [00:10<00:00, 19.13it/s]
# Train Acc: 44.16%
# MAE Linear Eval 4/5: 100% 196/196 [00:09<00:00, 19.71it/s]
# Train Acc: 45.11%
# MAE Linear Eval 5/5: 100% 196/196 [00:10<00:00, 19.15it/s]
# Train Acc: 46.04%
#
# ...

# %%
# !python3 run.py --model mae --mask-ratio 0.75 --epochs 50 --train
# Out:
# Using device: cuda
# /content/drive/MyDrive/A3-Self-Supervised-Learning/models.py:166: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=depth)
# /content/drive/MyDrive/A3-Self-Supervised-Learning/models.py:211: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(decoder_layer, num_layers=depth)
# MAE Encoder params: 2,678,976
# MAE Decoder params: 824,368 (30.8% of encoder)
# MAE 1/50: 100% 390/390 [00:13<00:00, 29.66it/s]
# Epoch 01 | Recon Loss: 0.7733 | Time: 13.2s
# MAE 2/50: 100% 390/390 [00:12<00:00, 30.46it/s]
# Epoch 02 | Recon Loss: 0.6612 | Time: 12.8s
# MAE 3/50: 100% 390/390 [00:11<00:00, 33.54it/s]
# Epoch 03 | Recon Loss: 0.6107 | Time: 11.6s
# MAE 4/50: 100% 390/390 [00:11<00:00, 34.14it/s]
# ...

# %%
# !python3 run.py --model mae    --weights saved/mae_encoder_mask075.pt --evaluate --linear
# Out:
# Using device: cuda
# /content/drive/MyDrive/A3-Self-Supervised-Learning/models.py:166: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=depth)
# /content/drive/MyDrive/A3-Self-Supervised-Learning/models.py:211: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(decoder_layer, num_layers=depth)
# MAE Linear Eval 1/5: 100% 196/196 [00:10<00:00, 19.35it/s]
# Train Acc: 35.25%
# MAE Linear Eval 2/5: 100% 196/196 [00:10<00:00, 18.75it/s]
# Train Acc: 43.19%
# MAE Linear Eval 3/5: 100% 196/196 [00:09<00:00, 19.80it/s]
# Train Acc: 45.30%
# MAE Linear Eval 4/5: 100% 196/196 [00:10<00:00, 19.31it/s]
# Train Acc: 46.61%
# MAE Linear Eval 5/5: 100% 196/196 [00:09<00:00, 19.79it/s]
# Train Acc: 47.59%
#
# ...

# %%
# !python3 plot_results.py
# Out:
# Using device: cuda
# Figure(1400x700)
# Saved figure to: figures/dino_mae_training_curves.png
# /content/drive/MyDrive/A3-Self-Supervised-Learning/models.py:166: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=depth)
# /content/drive/MyDrive/A3-Self-Supervised-Learning/models.py:211: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(decoder_layer, num_layers=depth)
# Figure(800x600)
# Reconstruction loss: 1.3112
# /usr/local/lib/python3.12/dist-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# Figure(800x2000)
# Running DINO linear evaluation to collect embeddings...
# ...
